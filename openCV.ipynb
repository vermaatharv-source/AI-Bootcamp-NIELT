# %%
# !pip install opencv-python
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !python -m pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in c:\users\verma_txgctcq\appdata\local\programs\python\python314\lib\site-packages (from opencv-python) (2.4.6)
# Downloading opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl (44.0 MB)
#    ---------------------------------------- 0.0/44.0 MB ? eta -:--:--
#    - -------------------------------------- 2.1/44.0 MB 14.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 5.2/44.0 MB 14.9 MB/s eta 0:00:03
#    ------- -------------------------------- 8.1/44.0 MB 14.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 12.1/44.0 MB 15.2 MB/s eta 0:00:03
#    ------------- -------------------------- 15.2/44.0 MB 15.3 MB/s eta 0:00:02
#    --------------- ------------------------ 17.6/44.0 MB 14.6 MB/s eta 0:00:02
#    ------------------ --------------------- 20.7/44.0 MB 14.6 MB/s eta 0:00:02
#    --------------------- ------------------ 24.1/44.0 MB 14.8 MB/s eta 0:00:02
#    ------------------------- -------------- 28.0/44.0 MB 15.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 32.0/44.0 MB 15.6 MB/s eta 0:00:01
#    -------------------------------- ------- 36.2/44.0 MB 16.1 MB/s eta 0:00:01
#    ------------------------------------ --- 40.1/44.0 MB 16.3 MB/s eta 0:00:01
#    ---------------------------------------  43.8/44.0 MB 16.5 MB/s eta 0:00:01
#    ---------------------------------------- 44.0/44.0 MB 16.0 MB/s  0:00:02
# Installing collected packages: opencv-python
# Successfully installed opencv-python-5.0.0.93
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
print("OpenCV installed successfully! Version:", cv2.__version__)
# Out:
# OpenCV installed successfully! Version: 5.0.0

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = cv2.imread('farmfresh-logo.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')
plt.show()
